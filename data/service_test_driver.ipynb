# %%
import json, requests

BASE = "http://localhost:3000/" # Local machine
# BASE = "http://192.168.99.100:3000/" # Local Docker instance
# BASE = "http://192.168.99.100:8080/idmapping/v1/" # Agent on Docker

# BASE = "http://54.200.201.85:3000/" # EC2


def jprint(data):
    print(json.dumps(data, indent=4))


with open("galcxStyle2.json") as json_file:
    cx = json.load(json_file)

# jprint(cx)

res1 = requests.post(BASE + "cx2cyjs", json=cx)
res_json = res1.json()

# print(len(res_json["matched"]))
jprint(res_json)
# jprint(json.loads(res_json))
# Out:
# {
#     "style": [
#         {
#             "css": {
#                 "background-opacity": 255,
#                 "font-size": 12,
#                 "font-family": "HelveticaNeue-UltraLight",
#                 "shape": "roundrectangle",
#                 "text-opacity": 255,
#                 "border-width": 0,
#                 "background-color": "#FFFF00",
#                 "width": 70,
#                 "border-opacity": 255,
#                 "height": 30,
#                 "color": "#333333"
#             },
#             "selector": "node"
#         },
#         {
#             "css": {
#                 "font-size": 10,
#                 "font-family": "Dialog",
#                 "opacity": 255,
#                 "text-opacity": 255,
#                 "line-style": "solid",
#                 "target-arrow-shape": "none",
#                 "width": 3,
#                 "line-color": "#666666",
#                 "source-arrow-shape": "none",
#                 "color": "#000000"
#             },
#             "selector": "edge"
#         },
#         {
#             "css": {
#                 "content": "leaf"
#             },
#             "selector": "node[degree.layout = 1]"
#         },
#         {
#             "css": {
#                 "width": 20
#             },
#             "selector": "node[BetweennessCentrality < 0.11051693558692932]"
#         },
#         {
#             "css": {
#                 "width": 20
#             },
#             "selector": "node[BetweennessCentrality = 0.11051693558692932]"
#         },
#         {
#             "css": {
#                 "width": "mapData(BetweennessCentrality,0.4000000059604645,0.8467023372650146,40.0,150.0)"
#             },
#             "selector": "node[BetweennessCentrality > 0.4000000059604645][BetweennessCentrality < 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "width": 150
#             },
#             "selector": "node[BetweennessCentrality = 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "width": "mapData(BetweennessCentrality,0.4000000059604645,0.8467023372650146,40.0,150.0)"
#             },
#             "selector": "node[BetweennessCentrality > 0.4000000059604645][BetweennessCentrality < 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "width": 150
#             },
#             "selector": "node[BetweennessCentrality = 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "width": 150
#             },
#             "selector": "node[BetweennessCentrality > 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "height": 20
#             },
#             "selector": "node[BetweennessCentrality < 0.11051693558692932]"
#         },
#         {
#             "css": {
#                 "height": 20
#             },
#             "selector": "node[BetweennessCentrality = 0.11051693558692932]"
#         },
#         {
#             "css": {
#                 "height": "mapData(BetweennessCentrality,0.4000000059604645,0.8467023372650146,40.0,150.0)"
#             },
#             "selector": "node[BetweennessCentrality > 0.4000000059604645][BetweennessCentrality < 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "height": 150
#             },
#             "selector": "node[BetweennessCentrality = 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "height": "mapData(BetweennessCentrality,0.4000000059604645,0.8467023372650146,40.0,150.0)"
#             },
#             "selector": "node[BetweennessCentrality > 0.4000000059604645][BetweennessCentrality < 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "height": 150
#             },
#             "selector": "node[BetweennessCentrality = 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "height": 150
#             },
#             "selector": "node[BetweennessCentrality > 0.8467023372650146]"
#         },
#         {
#             "css": {
#                 "background-color": "#FF8000"
#             },
#             "selector": "node[Degree = 1]"
#         },
#         {
#             "css": {
#                 "background-color": "#FFFF00"
#             },
#             "selector": "node[Degree = 2]"
#         },
#         {
#             "css": {
#                 "background-color": "#80FF00"
#             },
#             "selector": "node[Degree = 3]"
#         },
#         {
#             "css": {
#                 "background-color": "#00FF00"
#             },
#             "selector": "node[Degree = 4]"
#         },
#         {
#             "css": {
#                 "background-color": "#00FF80"
#             },
#             "selector": "node[Degree = 5]"
#         },
#         {
#             "css": {
#                 "background-color": "#00FFFF"
#             },
#             "selector": "node[Degree = 6]"
#         },
#         {
#             "css": {
#                 "background-color": "#0080FF"
#             },
#             "selector": "node[Degree = 7]"
#         },
#         {
#             "css": {
#                 "background-color": "#0000FF"
#             },
#             "selector": "node[Degree = 8]"
#         },
#         {
#             "css": {
#                 "background-color": "#7F00FF"
#             },
#             "selector": "node[Degree = 9]"
#         },
#         {
#             "css": {
#                 "background-color": "#FF00FF"
#             },
#             "selector": "node[Degree = 11]"
#         },
#         {
#             "css": {
#                 "background-color": "#FF0080"
#             },
#             "selector": "node[Degree = 17]"
#         },
#         {
#             "css": {
#                 "background-color": "#FF0000"
#             },
#             "selector": "node[Degree = 18]"
#         }
#     ],
#     "data": {
#         "__Annotations": [
#             ""
#         ],
#         "publication": "Integrated Genomic and Proteomic Analyses of a Systematically Perturbed Metabolic Network\nTrey Ideker, Vesteinn Thorsson, Jeffrey A. Ranish, Rowan Christmas, Jeremy Buhler, Jimmy K. Eng, Roger Bumgarner, David R. Goodlett, Ruedi Aebersold, and Leroy Hood\nScience 4 May 2001: 292 (5518), 929-934. [DOI:10.1126/science.292.5518.929]"
#     },
#     "cxData": {
#         "cyViews": [
#             {
#                 "@id": 2946,
#                 "s": 2228
#             }
#         ],
#         "hiddenAttributes": [
#             {
#                 "v": "Prefuse Force Directed Layout",
#                 "s": 2228,
#                 "n": "layoutAlgorithm"
#             }
#         ],
#         "status": [
#             {
#                 "success": true,
#                 "error": ""
#             }
#         ],
#         "subNetworks": [
#             {
#                 "@id": 2228,
#                 "edges": [
#                     2930,
#                     2929,
#                     2928,
#                     2927,
#                     2926,
#                     2925,
#                     2924,
#                     2923,
#                     2922,
#                     2921,
#                     2920,
#                     2919,
#                     2918,
#                     2917,
#                     2916,
#                     2915,
#                     2914,
#                     2913,
#                     2912,
#                     2911,
#                     2910,
#                     2909,
#                     2908,
#                     2907,
#                     2906,
#                     2905,
#                     2904,
#                     2903,
#                     2902,
#                     2901,
#                     2900,
#                     2899,
#                     2898,
#                     2897,
#                     2896,
#                     2895,
#                     2894,
#                     2893,
#                     2892,
#                     2891,
#                     2890,
#                     2889,
#                     2888,
#                     2887,
#                     2886,
#                     2885,
#                     2884,
#                     2883,
#                     2882,
#                     2881,
#                     2880,
#                     2879,
#                     2878,
#                     2877,
#                     2876,
#                     2875,
#                     2874,
#                     2873,
#                     2872,
#                     2871,
#                     2870,
#                     2869,
#                     2868,
#                     2867,
#                     2866,
#                     2865,
#                     2864,
#                     2863,
#                     2862,
#                     2861,
#                     2860,
#                     2859,
#                     2858,
#                     2857,
#                     2856,
#                     2855,
#                     2854,
#                     2853,
#                     2852,
#                     2851,
#                     2850,
#                     2849,
#                     2848,
#                     2847,
#                     2846,
#                     2845,
#                     2844,
#                     2843,
#                     2842,
#                     2841,
#                     2840,
#                     2839,
#                     2838,
#                     2837,
#                     2836,
#                     2835,
#                     2834,
#                     2833,
#                     2832,
#                     2831,
#                     2830,
#                     2829,
#                     2828,
#                     2827,
#                     2826,
#                     2825,
#                     2824,
#                     2823,
#                     2822,
#                     2821,
#                     2820,
#                     2819,
#                     2818,
#                     2817,
#                     2816,
#                     2815,
#                     2814,
#                     2813,
#                     2812,
#                     2811,
#                     2810,
#                     2809,
#                     2808,
#                     2807,
#                     2806,
#                     2805,
#                     2804,
#                     2803,
#                     2802,
#                     2801,
#                     2800,
#                     2799,
#                     2798,
#                     2797,
#                     2796,
#                     2795,
#                     2794,
#                     2793,
#                     2792,
#                     2791,
#                     2790,
#                     2789,
#                     2788,
#                     2787,
#                     2786,
#                     2785,
#                     2784,
#                     2783,
#                     2782,
#                     2781,
#                     2780,
#                     2779,
#                     2778,
#                     2777,
#                     2776,
#                     2775,
#                     2774,
#                     2773,
#                     2772,
#                     2771,
#                     2770,
#                     2769,
#                     2768,
#                     2767,
#                     2766,
#                     2765,
#                     2764,
#                     2763,
#                     2762,
#                     2761,
#                     2760,
#                     2759,
#                     2758,
#                     2757,
#                     2756,
#                     2755,
#                     2754,
#                     2753,
#                     2752,
#                     2751,
#                     2750,
#                     2749,
#                     2748,
#                     2747,
#                     2746,
#                     2745,
#                     2744,
#                     2743,
#                     2742,
#                     2741,
#                     2740,
#                     2739,
#                     2738,
#                     2737,
#                     2736,
#                     2735,
#                     2734,
#                     2733,
#                     2732,
#                     2731,
#                     2730,
#                     2729,
#                     2728,
#                     2727,
#                     2726,
#                     2725,
#                     2724,
#                     2723,
#                     2722,
#                     2721,
#                     2720,
#                     2719,
#                     2718,
#                     2717,
#                     2716,
#                     2715,
#                     2714,
#                     2713,
#                     2712,
#                     2711,
#                     2710,
#                     2709,
#                     2708,
#                     2707,
#                     2706,
#                     2705,
#                     2704,
#                     2703,
#                     2702,
#                     2701,
#                     2700,
#                     2699,
#                     2698,
#                     2697,
#                     2696,
#                     2695,
#                     2694,
#                     2693,
#                     2692,
#                     2691,
#                     2690,
#                     2689,
#                     2688,
#                     2687,
#                     2686,
#                     2685,
#                     2684,
#                     2683,
#                     2682,
#                     2681,
#                     2680,
#                     2679,
#                     2678,
#                     2677,
#                     2676,
#                     2675,
#                     2674,
#                     2673,
#                     2672,
#                     2671,
#                     2670,
#                     2669,
#                     2668,
#                     2667,
#                     2666,
#                     2665,
#                     2664,
#                     2663,
#                     2662,
#                     2661,
#                     2660,
#                     2659,
#                     2658,
#                     2657,
#                     2656,
#                     2655,
#                     2654,
#                     2653,
#                     2652,
#                     2651,
#                     2650,
#                     2649,
#                     2648,
#                     2647,
#                     2646,
#                     2645,
#                     2644,
#                     2643,
#                     2642,
#                     2641,
#                     2640,
#                     2639,
#                     2638,
#                     2637,
#                     2636,
#                     2635,
#                     2634,
#                     2633,
#                     2632,
#                     2631,
#                     2630,
#                     2629,
#                     2628,
#                     2627,
#                     2626,
#                     2625,
#                     2624,
#                     2623,
#                     2622,
#                     2621,
#                     2620,
#                     2619,
#                     2618,
#                     2617,
#                     2616,
#                     2615,
#                     2614,
#                     2613,
#                     2612,
#                     2611,
#                     2610,
#                     2609,
#                     2608,
#                     2607,
#                     2606,
#                     2605,
#                     2604,
#                     2603,
#                     2602,
#                     2601,
#                     2600,
#                     2599,
#                     2598,
#                     2597,
#                     2596,
#                     2595,
#                     2594,
#                     2593,
#                     2592,
#                     2591,
#                     2590,
#                     2589,
#                     2588,
#                     2587,
#                     2586,
#                     2585,
#                     2584,
#                     2583,
#                     2582,
#                     2581,
#                     2580,
#                     2579,
#                     2578,
#                     2577,
#                     2576,
#                     2575,
#                     2574,
#                     2573,
#                     2572,
#                     2571,
#                     2570,
#                     2569
#                 ],
#                 "nodes": [
#                     2568,
#                     2567,
#                     2566,
#                     2565,
#                     2564,
#                     2563,
#                     2562,
#                     2561,
#                     2560,
#                     2559,
#                     2558,
#                     2557,
#                     2556,
#                     2555,
#                     2554,
#                     2553,
#                     2552,
#                     2551,
#                     2550,
#                     2549,
#                     2548,
#                     2547,
#                     2546,
#                     2545,
#                     2544,
#                     2543,
#                     2542,
#                     2541,
#                     2540,
#                     2539,
#                     2538,
#                     2537,
#                     2536,
#                     2535,
#                     2534,
#                     2533,
#                     2532,
#                     2531,
#                     2530,
#                     2529,
#                     2528,
#                     2527,
#                     2526,
#                     2525,
#                     2524,
#                     2523,
#                     2522,
#                     2521,
#                     2520,
#                     2519,
#                     2518,
#                     2517,
#                     2516,
#                     2515,
#                     2514,
#                     2513,
#                     2512,
#                     2511,
#                     2510,
#                     2509,
#                     2508,
#                     2507,
#                     2506,
#                     2505,
#                     2504,
#                     2503,
#                     2502,
#                     2501,
#                     2500,
#                     2499,
#                     2498,
#                     2497,
#                     2496,
#                     2495,
#                     2494,
#                     2493,
#                     2492,
#                     2491,
#                     2490,
#                     2489,
#                     2488,
#                     2487,
#                     2486,
#                     2485,
#                     2484,
#                     2483,
#                     2482,
#                     2481,
#                     2480,
#                     2479,
#                     2478,
#                     2477,
#                     2476,
#                     2475,
#                     2474,
#                     2473,
#                     2472,
#                     2471,
#                     2470,
#                     2469,
#                     2468,
#                     2467,
#                     2466,
#                     2465,
#                     2464,
#                     2463,
#                     2462,
#                     2461,
#                     2460,
#                     2459,
#                     2458,
#                     2457,
#                     2456,
#                     2455,
#                     2454,
#                     2453,
#                     2452,
#                     2451,
#                     2450,
#                     2449,
#                     2448,
#                     2447,
#                     2446,
#                     2445,
#                     2444,
#                     2443,
#                     2442,
#                     2441,
#                     2440,
#                     2439,
#                     2438,
#                     2437,
#                     2436,
#                     2435,
#                     2434,
#                     2433,
#                     2432,
#                     2431,
#                     2430,
#                     2429,
#                     2428,
#                     2427,
#                     2426,
#                     2425,
#                     2424,
#                     2423,
#                     2422,
#                     2421,
#                     2420,
#                     2419,
#                     2418,
#                     2417,
#                     2416,
#                     2415,
#                     2414,
#                     2413,
#                     2412,
#                     2411,
#                     2410,
#                     2409,
#                     2408,
#                     2407,
#                     2406,
#                     2405,
#                     2404,
#                     2403,
#                     2402,
#                     2401,
#                     2400,
#                     2399,
#                     2398,
#                     2397,
#                     2396,
#                     2395,
#                     2394,
#                     2393,
#                     2392,
#                     2391,
#                     2390,
#                     2389,
#                     2388,
#                     2387,
#                     2386,
#                     2385,
#                     2384,
#                     2383,
#                     2382,
#                     2381,
#                     2380,
#                     2379,
#                     2378,
#                     2377,
#                     2376,
#                     2375,
#                     2374,
#                     2373,
#                     2372,
#                     2371,
#                     2370,
#                     2369,
#                     2368,
#                     2367,
#                     2366,
#                     2365,
#                     2364,
#                     2363,
#                     2362,
#                     2361,
#                     2360,
#                     2359,
#                     2358,
#                     2357,
#                     2356,
#                     2355,
#                     2354,
#                     2353,
#                     2352,
#                     2351,
#                     2350,
#                     2349,
#                     2348,
#                     2347,
#                     2346,
#                     2345,
#                     2344,
#                     2343,
#                     2342,
#                     2341,
#                     2340,
#                     2339,
#                     2338,
#                     2337,
#                     2336,
#                     2335,
#                     2334,
#                     2333,
#                     2332,
#                     2331,
#                     2330,
#                     2329,
#                     2328,
#                     2327,
#                     2326,
#                     2325,
#                     2324,
#                     2323,
#                     2322,
#                     2321,
#                     2320,
#                     2319,
#                     2318,
#                     2317,
#                     2316,
#                     2315,
#                     2314,
#                     2313,
#                     2312,
#                     2311,
#                     2310,
#                     2309,
#                     2308,
#                     2307,
#                     2306,
#                     2305,
#                     2304,
#                     2303,
#                     2302,
#                     2301,
#                     2300,
#                     2299,
#                     2298,
#                     2297,
#                     2296,
#                     2295,
#                     2294,
#                     2293,
#                     2292,
#                     2291,
#                     2290,
#                     2289,
#                     2288,
#                     2287,
#                     2286,
#                     2285,
#                     2284,
#                     2283,
#                     2282,
#                     2281,
#                     2280,
#                     2279,
#                     2278,
#                     2277,
#                     2276,
#                     2275,
#                     2274,
#                     2273,
#                     2272,
#                     2271,
#                     2270,
#                     2269,
#                     2268,
#                     2267,
#                     2266,
#                     2265,
#                     2264,
#                     2263,
#                     2262,
#                     2261,
#                     2260,
#                     2259,
#                     2258,
#                     2257,
#                     2256,
#                     2255,
#                     2254,
#                     2253,
#                     2252,
#                     2251,
#                     2250,
#                     2249,
#                     2248,
#                     2247,
#                     2246,
#                     2245,
#                     2244,
#                     2243,
#                     2242,
#                     2241,
#                     2240,
#                     2239,
#                     2238
#                 ]
#             }
#         ],
#         "metaData": [
#             {
#                 "consistencyGroup": 1,
#                 "name": "networkAttributes",
#                 "elementCount": 2,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "hiddenAttributes",
#                 "elementCount": 1,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "nodeAttributes",
#                 "elementCount": 7932,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "edgeAttributes",
#                 "elementCount": 1448,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "cartesianLayout",
#                 "elementCount": 331,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "visualProperties",
#                 "elementCount": 3,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "subNetworks",
#                 "elementCount": 1,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "cyViews",
#                 "elementCount": 1,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "cyGroups",
#                 "elementCount": 0,
#                 "version": "1.0"
#             },
#             {
#                 "consistencyGroup": 1,
#                 "name": "networkRelations",
#                 "elementCount": 2,
#                 "version": "1.0"
#             }
#         ],
#         "numberVerification": [
#             {
#                 "longNumber": 9.223372036854776e+18
#             }
#         ],
#         "networkRelations": [
#             {
#                 "p": 2228,
#                 "name": "galFiltered.sif view",
#                 "r": "view",
#                 "c": 2946
#             },
#             {
#                 "p": 2212,
#                 "name": "galFiltered.sif",
#                 "r": "subnetwork",
#                 "c": 2228
#             }
#         ]
#     },
#     "elements": {
#         "edges": [
#             {
#                 "data": {
#                     "id": "2930",
#                     "target": "2567",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YKR026C (pp) YGL122C",
#                     "source": "2568",
#                     "name": "YKR026C (pp) YGL122C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2929",
#                     "target": "2555",
#                     "EdgeBetweenness": 988,
#                     "interaction": "pp",
#                     "shared name": "YGL122C (pp) YOL123W",
#                     "source": "2567",
#                     "name": "YGL122C (pp) YOL123W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2928",
#                     "target": "2565",
#                     "EdgeBetweenness": 6,
#                     "interaction": "pp",
#                     "shared name": "YGR218W (pp) YGL097W",
#                     "source": "2566",
#                     "name": "YGR218W (pp) YGL097W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2927",
#                     "target": "2564",
#                     "EdgeBetweenness": 6,
#                     "interaction": "pp",
#                     "shared name": "YGL097W (pp) YOR204W",
#                     "source": "2565",
#                     "name": "YGL097W (pp) YOR204W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2926",
#                     "target": "2562",
#                     "EdgeBetweenness": 4,
#                     "interaction": "pp",
#                     "shared name": "YLR249W (pp) YPR080W",
#                     "source": "2563",
#                     "name": "YLR249W (pp) YPR080W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2925",
#                     "target": "2561",
#                     "EdgeBetweenness": 4,
#                     "interaction": "pp",
#                     "shared name": "YLR249W (pp) YBR118W",
#                     "source": "2563",
#                     "name": "YLR249W (pp) YBR118W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2924",
#                     "target": "2556",
#                     "EdgeBetweenness": 4,
#                     "interaction": "pp",
#                     "shared name": "YPR080W (pp) YAL003W",
#                     "source": "2562",
#                     "name": "YPR080W (pp) YAL003W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2923",
#                     "target": "2556",
#                     "EdgeBetweenness": 4,
#                     "interaction": "pp",
#                     "shared name": "YBR118W (pp) YAL003W",
#                     "source": "2561",
#                     "name": "YBR118W (pp) YAL003W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2922",
#                     "target": "2565",
#                     "EdgeBetweenness": 6,
#                     "interaction": "pp",
#                     "shared name": "YLR293C (pp) YGL097W",
#                     "source": "2560",
#                     "name": "YLR293C (pp) YGL097W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2921",
#                     "target": "2558",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YMR146C (pp) YDR429C",
#                     "source": "2559",
#                     "name": "YMR146C (pp) YDR429C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2920",
#                     "target": "2557",
#                     "EdgeBetweenness": 1470.49481074,
#                     "interaction": "pp",
#                     "shared name": "YDR429C (pp) YFL017C",
#                     "source": "2558",
#                     "name": "YDR429C (pp) YFL017C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2919",
#                     "target": "2326",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YFL017C (pp) YOL059W",
#                     "source": "2557",
#                     "name": "YFL017C (pp) YOL059W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2918",
#                     "target": "2325",
#                     "EdgeBetweenness": 2758.08455433,
#                     "interaction": "pp",
#                     "shared name": "YFL017C (pp) YER102W",
#                     "source": "2557",
#                     "name": "YFL017C (pp) YER102W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2917",
#                     "target": "2324",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YFL017C (pp) YOR362C",
#                     "source": "2557",
#                     "name": "YFL017C (pp) YOR362C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2916",
#                     "target": "2554",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YOL123W (pp) YGL044C",
#                     "source": "2555",
#                     "name": "YOL123W (pp) YGL044C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2915",
#                     "target": "2552",
#                     "EdgeBetweenness": 8,
#                     "interaction": "pp",
#                     "shared name": "YPL211W (pp) YGR014W",
#                     "source": "2553",
#                     "name": "YPL211W (pp) YGR014W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2914",
#                     "target": "2551",
#                     "EdgeBetweenness": 7,
#                     "interaction": "pp",
#                     "shared name": "YGR014W (pp) YJL030W",
#                     "source": "2552",
#                     "name": "YGR014W (pp) YJL030W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2913",
#                     "target": "2549",
#                     "EdgeBetweenness": 7,
#                     "interaction": "pp",
#                     "shared name": "YGR014W (pp) YJL013C",
#                     "source": "2552",
#                     "name": "YGR014W (pp) YJL013C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2912",
#                     "target": "2550",
#                     "EdgeBetweenness": 5,
#                     "interaction": "pp",
#                     "shared name": "YJL030W (pp) YGL229C",
#                     "source": "2551",
#                     "name": "YJL030W (pp) YGL229C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2911",
#                     "target": "2550",
#                     "EdgeBetweenness": 5,
#                     "interaction": "pp",
#                     "shared name": "YJL013C (pp) YGL229C",
#                     "source": "2549",
#                     "name": "YJL013C (pp) YGL229C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2910",
#                     "target": "2547",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YGR203W (pp) YIL061C",
#                     "source": "2548",
#                     "name": "YGR203W (pp) YIL061C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2909",
#                     "target": "2534",
#                     "EdgeBetweenness": 8486.71708292,
#                     "interaction": "pp",
#                     "shared name": "YIL061C (pp) YDL013W",
#                     "source": "2547",
#                     "name": "YIL061C (pp) YDL013W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2908",
#                     "target": "2389",
#                     "EdgeBetweenness": 9902.71708292,
#                     "interaction": "pp",
#                     "shared name": "YIL061C (pp) YNL199C",
#                     "source": "2547",
#                     "name": "YIL061C (pp) YNL199C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2907",
#                     "target": "2267",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YIL061C (pp) YLR153C",
#                     "source": "2547",
#                     "name": "YIL061C (pp) YLR153C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2906",
#                     "target": "2545",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YCR084C (pp) YBR112C",
#                     "source": "2546",
#                     "name": "YCR084C (pp) YBR112C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2905",
#                     "target": "2544",
#                     "EdgeBetweenness": 988,
#                     "interaction": "pp",
#                     "shared name": "YCR084C (pp) YCL067C",
#                     "source": "2546",
#                     "name": "YCR084C (pp) YCL067C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2904",
#                     "target": "2444",
#                     "EdgeBetweenness": 9,
#                     "interaction": "pd",
#                     "shared name": "YCL067C (pd) YIL015W",
#                     "source": "2544",
#                     "name": "YCL067C (pd) YIL015W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2903",
#                     "target": "2445",
#                     "EdgeBetweenness": 1447.5,
#                     "interaction": "pp",
#                     "shared name": "YCL067C (pp) YMR043W",
#                     "source": "2544",
#                     "name": "YCL067C (pp) YMR043W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2902",
#                     "target": "2440",
#                     "EdgeBetweenness": 9.83333333,
#                     "interaction": "pd",
#                     "shared name": "YCL067C (pd) YDR461W",
#                     "source": "2544",
#                     "name": "YCL067C (pd) YDR461W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2901",
#                     "target": "2437",
#                     "EdgeBetweenness": 9.83333333,
#                     "interaction": "pd",
#                     "shared name": "YCL067C (pd) YFL026W",
#                     "source": "2544",
#                     "name": "YCL067C (pd) YFL026W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2900",
#                     "target": "2542",
#                     "EdgeBetweenness": 248.5,
#                     "interaction": "pp",
#                     "shared name": "YER112W (pp) YOR167C",
#                     "source": "2543",
#                     "name": "YER112W (pp) YOR167C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2899",
#                     "target": "2540",
#                     "EdgeBetweenness": 1960,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YNR050C",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YNR050C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2898",
#                     "target": "2539",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YNL050C",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YNL050C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2897",
#                     "target": "2538",
#                     "EdgeBetweenness": 3050.14565435,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YEL015W",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YEL015W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2896",
#                     "target": "2542",
#                     "EdgeBetweenness": 1220.5,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YOR167C",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YOR167C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2895",
#                     "target": "2537",
#                     "EdgeBetweenness": 1220.5,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YLR264W",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YLR264W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2894",
#                     "target": "2536",
#                     "EdgeBetweenness": 6283.85994006,
#                     "interaction": "pp",
#                     "shared name": "YJR022W (pp) YNR053C",
#                     "source": "2541",
#                     "name": "YJR022W (pp) YNR053C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2893",
#                     "target": "2488",
#                     "EdgeBetweenness": 1476,
#                     "interaction": "pp",
#                     "shared name": "YNR050C (pp) YMR138W",
#                     "source": "2540",
#                     "name": "YNR050C (pp) YMR138W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2892",
#                     "target": "2403",
#                     "EdgeBetweenness": 3025.31048951,
#                     "interaction": "pp",
#                     "shared name": "YEL015W (pp) YML064C",
#                     "source": "2538",
#                     "name": "YEL015W (pp) YML064C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2891",
#                     "target": "2543",
#                     "EdgeBetweenness": 248.5,
#                     "interaction": "pp",
#                     "shared name": "YLR264W (pp) YER112W",
#                     "source": "2537",
#                     "name": "YLR264W (pp) YER112W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2890",
#                     "target": "2322",
#                     "EdgeBetweenness": 248.5,
#                     "interaction": "pp",
#                     "shared name": "YLR264W (pp) YOL149W",
#                     "source": "2537",
#                     "name": "YLR264W (pp) YOL149W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2889",
#                     "target": "2290",
#                     "EdgeBetweenness": 248.5,
#                     "interaction": "pp",
#                     "shared name": "YLR264W (pp) YBL026W",
#                     "source": "2537",
#                     "name": "YLR264W (pp) YBL026W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2888",
#                     "target": "2435",
#                     "EdgeBetweenness": 988,
#                     "interaction": "pp",
#                     "shared name": "YNR053C (pp) YJL203W",
#                     "source": "2536",
#                     "name": "YNR053C (pp) YJL203W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2887",
#                     "target": "2276",
#                     "EdgeBetweenness": 7118.71708292,
#                     "interaction": "pp",
#                     "shared name": "YNR053C (pp) YDL030W",
#                     "source": "2536",
#                     "name": "YNR053C (pp) YDL030W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2886",
#                     "target": "2534",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pp",
#                     "shared name": "YER116C (pp) YDL013W",
#                     "source": "2535",
#                     "name": "YER116C (pp) YDL013W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2885",
#                     "target": "2532",
#                     "EdgeBetweenness": 988,
#                     "interaction": "pp",
#                     "shared name": "YNL307C (pp) YAL038W",
#                     "source": "2533",
#                     "name": "YNL307C (pp) YAL038W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2884",
#                     "target": "2390",
#                     "EdgeBetweenness": 2034.76542347,
#                     "interaction": "pd",
#                     "shared name": "YAL038W (pd) YPL075W",
#                     "source": "2532",
#                     "name": "YAL038W (pd) YPL075W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2883",
#                     "target": "2530",
#                     "EdgeBetweenness": 2940.76542347,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YCR012W",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YCR012W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2882",
#                     "target": "2529",
#                     "EdgeBetweenness": 2148.76542347,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YGR254W",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YGR254W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2881",
#                     "target": "2528",
#                     "EdgeBetweenness": 2148.76542347,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YHR174W",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YHR174W"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2880",
#                     "target": "2527",
#                     "EdgeBetweenness": 2391,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YIL133C",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YIL133C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2879",
#                     "target": "2526",
#                     "EdgeBetweenness": 15620.15017205,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YLR044C",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YLR044C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2878",
#                     "target": "2525",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YOL120C",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YOL120C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2877",
#                     "target": "2524",
#                     "EdgeBetweenness": 496,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YNL301C",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YNL301C"
#                 }
#             },
#             {
#                 "data": {
#                     "id": "2876",
#                     "target": "2523",
#                     "EdgeBetweenness": 5079.35982906,
#                     "interaction": "pd",
#                     "shared name": "YNL216W (pd) YCL030C",
#                     "source": "2531",
#                     "name": "YNL216W (pd) YCL030C"
#                 }
# ...
#                     "y": 3965.9754665824003
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 0.0041386,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 19,
#                     "ClosenessCentrality": 0.10929925,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": -0.218,
#                     "gal80Rexp": 0.056,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "RPL31A",
#                     "Radiality": 0.69817802,
#                     "IsSingleNode": false,
#                     "name": "YDL075W",
#                     "AverageShortestPathLength": 9.14919355,
#                     "gal80Rsig": 0.38208,
#                     "id": "2249",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 8,
#                     "gal4RGexp": -0.451,
#                     "Stress": 0,
#                     "gal4RGsig": 1.5697e-06,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 2333.385781525227,
#                     "y": 120.27460566133959
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 2.6481e-07,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 19,
#                     "ClosenessCentrality": 0.10929925,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": -0.346,
#                     "gal80Rexp": -0.124,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "RPL16B",
#                     "Radiality": 0.69817802,
#                     "IsSingleNode": false,
#                     "name": "YNL069C",
#                     "AverageShortestPathLength": 9.14919355,
#                     "gal80Rsig": 0.026888,
#                     "id": "2248",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 8,
#                     "gal4RGexp": -0.284,
#                     "Stress": 0,
#                     "gal4RGsig": 5.1994e-05,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 2437.6053222920746,
#                     "y": 0.2937215777928941
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "name": "YER056CA",
#                     "TopologicalCoefficient": 0,
#                     "id": "2247",
#                     "ClusteringCoefficient": 0,
#                     "ClosenessCentrality": 0.10929925,
#                     "NeighborhoodConnectivity": 8,
#                     "Eccentricity": 19,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "AverageShortestPathLength": 9.14919355,
#                     "SelfLoops": 0,
#                     "NumberOfDirectedEdges": 1,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "IsSingleNode": false,
#                     "COMMON": "",
#                     "Radiality": 0.69817802,
#                     "Stress": 0,
#                     "Degree": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 2452.7783719702857,
#                     "y": 223.0725620725425
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 3.7855e-05,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 19,
#                     "ClosenessCentrality": 0.10929925,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": -0.258,
#                     "gal80Rexp": -0.025,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "RPL34B",
#                     "Radiality": 0.69817802,
#                     "IsSingleNode": false,
#                     "name": "YIL052C",
#                     "AverageShortestPathLength": 9.14919355,
#                     "gal80Rsig": 0.66627,
#                     "id": "2246",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 8,
#                     "gal4RGexp": -0.451,
#                     "Stress": 0,
#                     "gal4RGsig": 3.4652e-07,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 2556.0962966172956,
#                     "y": 104.12964743655175
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 0.012373,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 19,
#                     "ClosenessCentrality": 0.10968598,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.108,
#                     "gal80Rexp": 0.116,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "YLR345W",
#                     "Radiality": 0.69937276,
#                     "IsSingleNode": false,
#                     "name": "YLR345W",
#                     "AverageShortestPathLength": 9.11693548,
#                     "gal80Rsig": 0.073789,
#                     "id": "2245",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 2,
#                     "gal4RGexp": 0.234,
#                     "Stress": 0,
#                     "gal4RGsig": 7.892e-05,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 2682.7898754801718,
#                     "y": 3081.3231172774103
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 0.00025668,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 3,
#                     "ClosenessCentrality": 0.5,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": -0.186,
#                     "gal80Rexp": -0.42,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "NUP170",
#                     "Radiality": 0.66666667,
#                     "IsSingleNode": false,
#                     "name": "YBL079W",
#                     "AverageShortestPathLength": 2,
#                     "gal80Rsig": 2.9469e-09,
#                     "id": "2244",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 2,
#                     "gal4RGexp": -0.032,
#                     "Stress": 0,
#                     "gal4RGsig": 0.45723,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 1992.9565749727772,
#                     "y": 3966.507440937101
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 5.5911e-06,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 20,
#                     "ClosenessCentrality": 0.10367893,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.786,
#                     "gal80Rexp": 0.94,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 3,
#                     "TopologicalCoefficient": 0.44444444,
#                     "COMMON": "GIP1",
#                     "Radiality": 0.67980884,
#                     "IsSingleNode": false,
#                     "name": "YBR045C",
#                     "AverageShortestPathLength": 9.64516129,
#                     "gal80Rsig": 0.016389,
#                     "id": "2243",
#                     "Degree": 3,
#                     "NeighborhoodConnectivity": 2.33333333,
#                     "gal4RGexp": 1.022,
#                     "Stress": 21474,
#                     "gal4RGsig": 1.2945e-05,
#                     "NumberOfDirectedEdges": 3,
#                     "BetweennessCentrality": 0.08528144
#                 },
#                 "position": {
#                     "x": 1061.6477041800972,
#                     "y": 2024.5283461958752
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 0.16958,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 19,
#                     "ClosenessCentrality": 0.11339735,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.057,
#                     "gal80Rexp": 0.247,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 2,
#                     "TopologicalCoefficient": 0.58333333,
#                     "COMMON": "GIP2",
#                     "Radiality": 0.71042413,
#                     "IsSingleNode": false,
#                     "name": "YER054C",
#                     "AverageShortestPathLength": 8.81854839,
#                     "gal80Rsig": 0.0043603,
#                     "id": "2242",
#                     "Degree": 2,
#                     "NeighborhoodConnectivity": 4.5,
#                     "gal4RGexp": 0.206,
#                     "Stress": 11544,
#                     "gal4RGsig": 0.00062032,
#                     "NumberOfDirectedEdges": 2,
#                     "BetweennessCentrality": 0.04427321
#                 },
#                 "position": {
#                     "x": 1399.4421817144612,
#                     "y": 2133.0566923914594
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 3.174e-05,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 18,
#                     "ClosenessCentrality": 0.10205761,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": -0.195,
#                     "gal80Rexp": -0.232,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "ASN1",
#                     "Radiality": 0.67413381,
#                     "IsSingleNode": false,
#                     "name": "YPR145W",
#                     "AverageShortestPathLength": 9.7983871,
#                     "gal80Rsig": 0.0011873,
#                     "id": "2241",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 3,
#                     "gal4RGexp": -0.614,
#                     "Stress": 0,
#                     "gal4RGsig": 1.1525e-07,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 4504.709487242217,
#                     "y": 3789.4705762051162
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 5.373e-08,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 2,
#                     "ClosenessCentrality": 0.66666667,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.454,
#                     "gal80Rexp": 0,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "YBR043C",
#                     "Radiality": 0.75,
#                     "IsSingleNode": false,
#                     "name": "YBR043C",
#                     "AverageShortestPathLength": 1.5,
#                     "gal80Rsig": 0.999999,
#                     "id": "2240",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 2,
#                     "gal4RGexp": 0.023,
#                     "Stress": 0,
#                     "gal4RGsig": 0.94178,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 3092.620042801893,
#                     "y": 3966.507440937101
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 2.186e-05,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 25,
#                     "ClosenessCentrality": 0.08250166,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.243,
#                     "gal80Rexp": 0.448,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 2,
#                     "TopologicalCoefficient": 0.5,
#                     "COMMON": "MTH1",
#                     "Radiality": 0.58811231,
#                     "IsSingleNode": false,
#                     "name": "YDR277C",
#                     "AverageShortestPathLength": 12.12096774,
#                     "gal80Rsig": 0.0005727,
#                     "id": "2239",
#                     "Degree": 2,
#                     "NeighborhoodConnectivity": 4,
#                     "gal4RGexp": 0.192,
#                     "Stress": 2722,
#                     "gal4RGsig": 0.028044,
#                     "NumberOfDirectedEdges": 2,
#                     "BetweennessCentrality": 0.00806452
#                 },
#                 "position": {
#                     "x": 156.11431560874917,
#                     "y": 3500.5138544587535
#                 }
#             },
#             {
#                 "selected": false,
#                 "data": {
#                     "gal1RGsig": 0.018043,
#                     "ClusteringCoefficient": 0,
#                     "Eccentricity": 26,
#                     "ClosenessCentrality": 0.07623732,
#                     "PartnerOfMultiEdgedNodePairs": 0,
#                     "gal1RGexp": 0.139,
#                     "gal80Rexp": 0.449,
#                     "SelfLoops": 0,
#                     "NumberOfUndirectedEdges": 0,
#                     "degree.layout": 1,
#                     "TopologicalCoefficient": 0,
#                     "COMMON": "SNF3",
#                     "Radiality": 0.55122461,
#                     "IsSingleNode": false,
#                     "name": "YDL194W",
#                     "AverageShortestPathLength": 13.11693548,
#                     "gal80Rsig": 0.011348,
#                     "id": "2238",
#                     "Degree": 1,
#                     "NeighborhoodConnectivity": 2,
#                     "gal4RGexp": 0.333,
#                     "Stress": 0,
#                     "gal4RGsig": 0.033961,
#                     "NumberOfDirectedEdges": 1,
#                     "BetweennessCentrality": 0
#                 },
#                 "position": {
#                     "x": 100.2170017536846,
#                     "y": 3597.162113253202
#                 }
#             }
#         ]
#     }
# }

# %%
import json, requests

# Utility function to display JSON
def jprint(data):
    print(json.dumps(data, indent=4))

# Mixed species query allowed - human, mouse, yeast, and fly
query = {
    "ids": ["Antp", "HOXA7"],
    "idTypes": ["GeneID", "Symbol", "UniProtKB-ID", "Synonyms"]
}

res = requests.post(BASE + 'map', json=query1)
jprint(res1.json())

# %%
yeast_genes = pd.read_csv("./yeast_genes.txt", names=["GeneID"], dtype={"GeneID": str})
print(len(yeast_genes))

id_list = yeast_genes["GeneID"].tolist()

query_heavy = {
    "ids": id_list, # List of yeast genes
        "idTypes": ["GeneID", "Symbol", "UniProtKB-ID"]
}

# %%
res_large = requests.post(BASE + 'map', data=json.dumps(query_heavy), headers=HEADERS)

jprint(res_large.json())

# %% [markdown]
# ## test with very large input
#
# Such file can be created from BioGRID networks...
#
# ```bash
# cat BIOGRID-ORGANISM-Homo_sapiens-3.4.129.mitab | awk -F"\t" '{print $1 "\n" $2}' | awk -F":" '{print $2}' | uniq > ~/Desktop/human_genes_list_large.txt
# ```

# %%
import pandas as pd

large_gene_list = pd.read_csv("./human_genes_list_large.txt", names=["GeneID"], dtype={"GeneID": str})

# %%
len(large_gene_list)

# %%
id_list = large_gene_list["GeneID"].tolist()

query_heavy = {
    "ids": id_list, # Huge list!
}

res_large = requests.post(BASE + 'map', data=json.dumps(query_heavy), headers=HEADERS)

# %%
largeJS = res_large.json()

print(len(largeJS))

# %%
# Randomly pick 100 IDs from original list
import random

list_size = len(id_list)

def call_random(server_location):
    random_ids = []

    for i in range(0, 2000):
        next_id = id_list[random.randint(0, list_size-1)]
        random_ids.append(next_id)

    query_rand = {
        "ids": random_ids,
    }

    res_rand = requests.post(server_location + 'map', data=json.dumps(query_rand), headers=HEADERS)

# %%
# %%timeit -n 100

call_random("http://192.168.99.100:3000/")

# %%
# %%timeit -n 100

call_random("http://192.168.99.100:8080/idmapping/v1/")
